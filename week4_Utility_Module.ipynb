# %% [markdown]
# # Week 4: Utility Module Project
# # **Student Name:** MUSKAN RAJPUT
# # **Functions:** Factorial, Prime Check, Square Root

# %%
# %%writefile utility.py
import math

def factorial(number): 
    result = 1   
    
    for value in range(1, number + 1):    
        result = result * value   
        
    return result 
    
def prime_check(number): 
    if number < 2:     
        return False  
        
    for value in range(2, number):  
        if number % value == 0:    
            return False   
            
    return True
    
def square_root(number): 
    return math.sqrt(number)
# Out:
# Overwriting utility.py

# %%
import utility

# %%
print("Factorial of 5:",
utility.factorial(5))
print("Is 7 prime?:", 
utility.prime_check(7))
print("Square root of 25:", 
utility.square_root(25))
# Out:
# Factorial of 5: 120
# Is 7 prime?: True
# Square root of 25: 5.0

# %%
print("===== UTILITY PROGRAM =====") 

# Factorial
factorial_number = int(input("Enter a number for factorial: "))

if factorial_number < 0: 
    print("Factorial is not available for negative numbers.")
else:  
    answer = utility.factorial(factorial_number)
    print("Factorial:", answer)
    
# Prime number check 
prime_number = int(input("Enter a number to check prime: ")) 

if utility.prime_check(prime_number) == True: 
    print(prime_number, "is a prime number.")
else:  
    print(prime_number, "is not a prime number.") 
    
# Square root
root_number = float(input("Enter a number for square root: "))

if root_number < 0:  
    print("Square root of a negative number is not allowed.") 
else:  
    answer = utility.square_root(root_number) 
    print("Square root:", answer)
# Out:
# ===== UTILITY PROGRAM =====
# Enter a number for factorial:  5
# Factorial: 120
# Enter a number to check prime:  7
# 7 is a prime number.
# Enter a number for square root:  64
# Square root: 8.0
